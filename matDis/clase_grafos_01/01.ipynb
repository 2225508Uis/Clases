# %%
from matplotlib.pyplot import *
from networkx import *

# %%
Grafo1=Graph()
Grafo1.add_node("A")
Grafo1.add_node("B")
Grafo1.add_node("C")
Grafo1.add_node("D")
Grafo1.add_node("E")



Grafo1.add_edge("A", "B")
Grafo1.add_edge("A", "C")

Grafo1.add_edge("C", "B")
Grafo1.add_edge("C", "D")
Grafo1.add_edge("C", "E")

Grafo1.add_edge("B", "D")

Grafo1.add_edge("D", "E")



draw(Grafo1, with_labels=True)
show()

# %%
Grafo2=Graph
Grafo2.add_edges_from(["A","B","C"])
